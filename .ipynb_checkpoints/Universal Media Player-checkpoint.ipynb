# %%
The Goal: Create a base Media class with a play() method. 
    Then, create subclasses like Song, Movie, 
and Podcast that inherit from Media and override the play() method to output unique processing messages 
    (e.g., "Playing audio...", "Playing video at 1080p...", "Playing podcast..."). 
        Finally, write a standalone function play_all(media_list) that loops through 
a list containing different media objects and triggers the play() method on each one, 
demonstrating how a single function handles different object types interchangeably. 
Concepts Tested: Polymorphism, Method Overriding, Inheritance, Duck Typing.

# %%
class Media:
    def play(self):
        pass
class Song(Media):
    def play(self):
        return "Playing audio..."
class Movie(Media):
    def play(self):
        return "Playing video at 1080p..."
class Podcast(Media):
    def play(self):
        return "Playing podcast..."
def play_all(media_list):
    for media in media_list:
        print(media.play())
song = Song()
movie = Movie()
podcast = Podcast()
play_all([song, movie, podcast])
# Out:
# Playing audio...
# Playing video at 1080p...
# Playing podcast...
